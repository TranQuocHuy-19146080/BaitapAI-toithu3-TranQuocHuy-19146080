# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
import numpy as np
import os 
import tensorflow as tf
import matplotlib.pyplot as plt
import pickle
import random
from tqdm import tqdm

# %%
datadir = "/content/drive/MyDrive/AI test/Group FaceID"
categories=['Quoc Huy','Thanh Nhan','Phu Hung']
img_size=100
for category in categories:
  path=os.path.join(datadir,category)
  for img in os.listdir(path):
    img_array = cv.imread(os.path.join(path,img),cv.IMREAD_GRAYSCALE)
    new_array = cv.resize(img_array,(img_size,img_size))
    print(new_array)
    plt.imshow(new_array,cmap='gray')
    plt.show()
    break
  break
# Out:
# [[218 219 219 ... 235 238 237]
#  [219 219 218 ... 236 237 238]
#  [219 220 219 ... 238 239 239]
#  ...
#  [ 91 100 101 ...  94 104 105]
#  [ 81  88 105 ... 101 106  97]
#  [ 85 104  86 ... 110 102  98]]

# %%
#creating training data
training_data=[]
def create_traning_data():

  for category in categories:
    path = os.path.join(datadir,category)
    class_num = categories.index(category)

    for img in tqdm(os.listdir(path)):
      try:
        img_array = cv.imread(os.path.join(path,img),cv.IMREAD_GRAYSCALE)
        new_array = cv.resize(img_array,(img_size,img_size))
        training_data.append([new_array,class_num])
      except Exception as e:
        pass
create_traning_data()
print(len(training_data))
# Out:
# 100%|██████████| 30/30 [00:28<00:00,  1.05it/s]
# 100%|██████████| 30/30 [00:25<00:00,  1.18it/s]
# 100%|██████████| 30/30 [00:28<00:00,  1.05it/s]
# 90

# %%
#saving (x:picture), (y:label)
X=[]
y=[]
for features, label in training_data :
  X.append(features)
  y.append(label)
X=np.array(X).reshape(-1,img_size,img_size,1)
y=np.array(y)
print('X',X.shape)
print('y',y.shape)
# Out:
# X (90, 100, 100, 1)
# y (90,)

# %%
#saving x, y as file.pickle into drive
pickle_out=open("/content/drive/MyDrive/AI test/Group FaceID/save/X.pickle","wb")
pickle.dump(X,pickle_out)
pickle_out.close()

pickle_out=open("/content/drive/MyDrive/AI test/Group FaceID/save/y.pickle","wb")
pickle.dump(y,pickle_out)
pickle_out.close()

# %%
#BUILD MODEL
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from tensorflow.keras.layers import Conv2D
from keras.layers.convolutional import MaxPooling2D
from tensorflow.keras.utils import to_categorical

# %%
pickle_in = open("/content/drive/MyDrive/AI test/Group FaceID/save/X.pickle","rb")
X= pickle.load(pickle_in)

pickle_in = open("/content/drive/MyDrive/AI test/Group FaceID/save/y.pickle","rb")
y= pickle.load(pickle_in)

X=X/255.0
print('X',X.shape)
print('y',y.shape)
# Out:
# X (90, 100, 100, 1)
# y (90,)

# %%
y= to_categorical(y,3)

# %%
model=Sequential()
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same',input_shape=(100,100,1)))
model.add(Conv2D(32,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(Conv2D(64,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(Conv2D(128,(3,3),activation='relu',kernel_initializer='he_uniform',padding='same'))
model.add(MaxPooling2D((2,2)))

model.add(Flatten())
model.add(Dense(128,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(3,activation='softmax'))

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.optimizers import SGD,Adam
opt =Adam()
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
history=model.fit(X,y,epochs=30,batch_size=64,validation_split=0.1,verbose=1)
# Out:
# Epoch 1/30
# 2/2 [==============================] - 14s 905ms/step - loss: 4.1251 - accuracy: 0.3827 - val_loss: 6.2628 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 2/2 [==============================] - 0s 73ms/step - loss: 1.8116 - accuracy: 0.6667 - val_loss: 0.5020 - val_accuracy: 1.0000
# Epoch 3/30
# 2/2 [==============================] - 0s 75ms/step - loss: 1.1534 - accuracy: 0.2593 - val_loss: 1.3735 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.8810 - accuracy: 0.4074 - val_loss: 0.7114 - val_accuracy: 1.0000
# Epoch 5/30
# 2/2 [==============================] - 0s 82ms/step - loss: 0.8076 - accuracy: 0.6914 - val_loss: 0.7404 - val_accuracy: 1.0000
# Epoch 6/30
# 2/2 [==============================] - 0s 70ms/step - loss: 0.5944 - accuracy: 0.9012 - val_loss: 0.3792 - val_accuracy: 1.0000
# Epoch 7/30
# 2/2 [==============================] - 0s 70ms/step - loss: 0.3723 - accuracy: 0.9383 - val_loss: 0.1205 - val_accuracy: 1.0000
# Epoch 8/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1381 - accuracy: 1.0000 - val_loss: 0.0100 - val_accuracy: 1.0000
# Epoch 9/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1567 - accuracy: 0.9383 - val_loss: 0.0105 - val_accuracy: 1.0000
# Epoch 10/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.2851 - accuracy: 0.8889 - val_loss: 0.7194 - val_accuracy: 0.6667
# Epoch 11/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.7744 - accuracy: 0.6543 - val_loss: 0.0073 - val_accuracy: 1.0000
# Epoch 12/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.3794 - accuracy: 0.8519 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 13/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1343 - accuracy: 0.9383 - val_loss: 0.0652 - val_accuracy: 1.0000
# Epoch 14/30
# 2/2 [==============================] - 0s 73ms/step - loss: 0.0302 - accuracy: 1.0000 - val_loss: 0.1701 - val_accuracy: 1.0000
# Epoch 15/30
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1103 - accuracy: 0.9506 - val_loss: 0.1177 - val_accuracy: 1.0000
# Epoch 16/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.1084 - accuracy: 0.9383 - val_loss: 0.0198 - val_accuracy: 1.0000
# Epoch 17/30
# 2/2 [==============================] - 0s 75ms/step - loss: 0.0351 - accuracy: 0.9877 - val_loss: 0.0038 - val_accuracy: 1.0000
# Epoch 18/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.0013 - val_accuracy: 1.0000
# Epoch 19/30
# 2/2 [==============================] - 0s 72ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0016 - val_accuracy: 1.0000
# Epoch 20/30
# 2/2 [==============================] - 0s 74ms/step - loss: 0.0081 - accuracy: 1.0000 - val_loss: 0.0011 - val_accuracy: 1.0000
# Epoch 21/30
# 2/2 [==============================] - 0s 71ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 5.2797e-04 - val_accuracy: 1.0000
# Epoch 22/30
# 2/2 [==============================] - 0s 76ms/step - loss: 3.0677e-04 - accuracy: 1.0000 - val_loss: 2.7353e-04 - val_accuracy: 1.0000
# Epoch 23/30
# 2/2 [==============================] - 0s 82ms/step - loss: 9.6639e-05 - accuracy: 1.0000 - val_loss: 1.6875e-04 - val_accuracy: 1.0000
# Epoch 24/30
# 2/2 [==============================] - 0s 76ms/step - loss: 9.2053e-05 - accuracy: 1.0000 - val_loss: 1.2924e-04 - val_accuracy: 1.0000
# Epoch 25/30
# 2/2 [==============================] - 0s 72ms/step - loss: 1.1457e-04 - accuracy: 1.0000 - val_loss: 1.1950e-04 - val_accuracy: 1.0000
# Epoch 26/30
# 2/2 [==============================] - 0s 77ms/step - loss: 1.5263e-04 - accuracy: 1.0000 - val_loss: 1.2221e-04 - val_accuracy: 1.0000
# Epoch 27/30
# 2/2 [==============================] - 0s 70ms/step - loss: 1.7605e-04 - accuracy: 1.0000 - val_loss: 1.2868e-04 - val_accuracy: 1.0000
# Epoch 28/30
# 2/2 [==============================] - 0s 72ms/step - loss: 2.1411e-04 - accuracy: 1.0000 - val_loss: 1.3297e-04 - val_accuracy: 1.0000
# Epoch 29/30
# 2/2 [==============================] - 0s 71ms/step - loss: 2.4763e-04 - accuracy: 1.0000 - val_loss: 1.3127e-04 - val_accuracy: 1.0000
# Epoch 30/30
# 2/2 [==============================] - 0s 71ms/step - loss: 2.3183e-04 - accuracy: 1.0000 - val_loss: 1.2668e-04 - val_accuracy: 1.0000

# %%
model.save('FaceID.h5')

# %%
img_test='/content/drive/MyDrive/AI test/Group FaceID/Thanh Nhan/Thanh Nhan 10.jpg'
categories=['Quoc Huy','Thanh Nhan','Phu Hung']
def prepare (filepath):
  img_size=100
  img_array=cv.imread(filepath, cv.IMREAD_GRAYSCALE)
  new_array=cv.resize(img_array,(100,100))
  new_array=new_array/255.0
  return new_array.reshape(-1,100,100,1)
plt.imshow(np.squeeze(prepare(img_test)),cmap='gray')
plt.show()

# %%
from keras.preprocessing.image import load_img,img_to_array
img1=load_img(img_test,target_size=(100,100))
img1_tensor=img_to_array(img1)
img1_tensor=np.expand_dims(img1_tensor,axis=0)
img1_tensor /= 255
plt.imshow(np.squeeze(img1_tensor))
plt.show()
prediction=model.predict([prepare(img_test)])
print('Prediction value',categories[int(np.argmax(prediction))])
# Out:
# Prediction value Thanh Nhan

# %%
from keras.models import load_model
# load and prepare the image
def load_image(filename):
	# load the image
	img = load_img(filename, target_size=(100, 100))	
	
	return img
labels = {0: 'Quoc Huy',
          1: 'Thanh Nhan', 
          2: 'Phu Hung',   
          }
model = load_model('FaceID.h5')
	# load model
img = load_image('/content/drive/MyDrive/AI test/Group FaceID/Quoc Huy/Quoc Huy 23.jpg')
plt.imshow(img)
img = img_to_array(img)
img.shape
img = cv.cvtColor(img,cv.COLOR_BGR2GRAY)
img = img.reshape(1,100,100,1)  
img.shape
result = model.predict(img)
print(result)
np.argmax(result) 
print('expectation',labels[np.argmax(result)])
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fc24eb299e0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# [[0. 0. 1.]]
# expectation Phu Hung
